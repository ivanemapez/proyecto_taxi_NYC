# %% [markdown]
# # Explicación de la APi aplicada al negocio.
#
# Esta API puede ser una herramienta poderosa para empresas y emprendedores en sectores relacionados con transporte, logística, o cualquier servicio basado en movilidad (como delivery o transporte de pasajeros). A continuación, te detallaré cómo esta API aporta valor al negocio:
#
# 1. Identificación de Zonas con Mayor Demanda
# - Problema del negocio: Conductores y empresas a menudo no saben en qué zonas concentrar sus esfuerzos para maximizar ingresos.
# - Solución con la API:
#     + La API identifica las zonas con mayor demanda para cada día de la semana, proporcionando información precisa sobre:
#         - Zonas más activas.
#         - Horas pico de actividad.
#         - Ganancias promedio en esas zonas.
#     + Impacto:
#         - Permite a las empresas asignar sus recursos (conductores, vehículos) de manera más eficiente.
#         - Reduce el tiempo de espera o inactividad para los conductores, maximizando los ingresos por hora.
#
# 2. Predicción de Ganancias Basada en el Contexto
# - Problema del negocio: Los conductores y las empresas necesitan estimar ingresos futuros para planificar sus operaciones y horarios.
# - Solución con la API:
#     + Usando un modelo de Machine Learning, la API predice las ganancias promedio esperadas según:
#         - Zona específica.
#         - Hora del día.
#         - Día de la semana.
#     + Impacto:
#         - Los conductores pueden planificar mejor sus horarios, enfocándose en momentos de alta rentabilidad.
#         - Las empresas pueden usar estas predicciones para ajustar tarifas dinámicas en función de la demanda estimada.
# 3. Optimización de Rutas y Tiempos
# - Problema del negocio: Los conductores a menudo recorren grandes distancias sin pasajeros, incurriendo en costos adicionales de combustible y tiempo.
# - Solución con la API:
#     + La API proporciona:
#         - Información geográfica con enlaces directos a Google Maps para cada zona de alta demanda.
#         - Distancias promedio recorridas en cada zona.
#     + Impacto:
#         - Optimiza rutas para minimizar desplazamientos sin pasajeros.
#         - Ayuda a reducir costos operativos (combustible, desgaste del vehículo).
# 4. Planificación Estratégica para la Empresa
# - Problema del negocio: Las empresas de transporte necesitan datos concretos para tomar decisiones estratégicas, como:
#     + Dónde expandir operaciones.
#     + Cómo ajustar tarifas.
#     + En qué zonas priorizar campañas de marketing.
# - Solución con la API:
#     + Con datos históricos y predicciones:
#         - Las empresas pueden identificar patrones de demanda estacional o diaria.
#         - Permite optimizar precios en zonas y horarios de alta demanda para maximizar ingresos.
#     + Impacto: Mejora la eficiencia operativa y la experiencia del cliente al reducir tiempos de espera y ajustar tarifas de manera más precisa.
# 5. Escenarios de Aplicación
#     - Conductores independientes: Usan la API para decidir dónde y cuándo trabajar, asegurando que maximizan sus ingresos por hora.
#     - Plataformas de transporte: Integran la API en su backend para ajustar tarifas dinámicas en tiempo real o sugerir zonas activas a los conductores.
#     - Empresas de logística y delivery: Optimizan las rutas de entrega basadas en datos de alta actividad, reduciendo costos y tiempos de entrega.
#     - Gobiernos o ciudades inteligentes: Analizan los datos para planificar infraestructura urbana, como estaciones de carga para vehículos eléctricos o mejoras en el transporte público.
# 6. Beneficios Clave para el Negocio
# - Maximización de ingresos: Información basada en datos históricos y predicciones permite a los conductores y empresas aprovechar los momentos y lugares más rentables.
# - Reducción de costos: Optimización de rutas y reducción de desplazamientos innecesarios.
# - Mejor experiencia del cliente: Reducción de tiempos de espera y disponibilidad más eficiente.
# - Toma de decisiones basada en datos: Estrategias operativas respaldadas por análisis de patrones históricos.
#
# 7. Conclusión
# Esta API no solo resuelve problemas operativos en tiempo real, sino que también proporciona una base sólida para decisiones estratégicas a largo plazo. Implementarla puede significar una ventaja competitiva significativa en industrias donde cada minuto y cada kilómetro cuentan para el éxito del negocio.

# %%
from fastapi import FastAPI
import pandas as pd
import numpy as np
import plotly.express as px
from fastapi.responses import FileResponse, JSONResponse
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# Load datasets
taxi_data_path = 'Yellow_Tripdata_2024-10.csv'
zone_data_path = 'transformed_taxi_zone_merged_with_locations.csv'

taxi_data = pd.read_csv(taxi_data_path)
zone_data = pd.read_csv(zone_data_path)

# Create FastAPI app
app = FastAPI()

# Preprocess data
# Merge datasets and extract necessary columns
data = taxi_data.merge(zone_data, left_on='PULocationID', right_on='locationid_x', how='left')
data['pickup_hour'] = pd.to_datetime(data['tpep_pickup_datetime']).dt.hour
data['pickup_day'] = pd.to_datetime(data['tpep_pickup_datetime']).dt.day_name()

def calculate_weekly_demand(day_of_week):
    # Filter data for the selected day
    day_data = data[data['pickup_day'] == day_of_week]

    # Group by zones and calculate metrics
    zone_summary = (
        day_data.groupby('zone')
        .agg({
            'fare_amount': 'mean',
            'trip_distance': 'mean',
            'PULocationID': 'count',
            'zone_latitude': 'mean',
            'zone_longitude': 'mean',
            'pickup_hour': lambda x: x.value_counts().idxmax()  # Most common hour
        })
        .rename(columns={
            'fare_amount': 'avg_earning',
            'trip_distance': 'avg_distance',
            'PULocationID': 'trip_count',
            'pickup_hour': 'peak_hour'
        })
        .reset_index()
    )

    # Sort zones by trip count
    zone_summary = zone_summary.sort_values(by='trip_count', ascending=False)

    # Add Google Maps URL
    zone_summary['maps_url'] = zone_summary.apply(
        lambda row: f"https://www.google.com/maps?q={row['zone_latitude']},{row['zone_longitude']}", axis=1
    )

    return zone_summary[['zone', 'peak_hour', 'avg_earning', 'avg_distance', 'trip_count', 'maps_url']]

def generate_demand_chart(day_of_week, filename='demand_chart.png'):
    day_data = calculate_weekly_demand(day_of_week)
    fig = px.bar(
        day_data,
        x='zone',
        y='trip_count',
        color='avg_earning',
        title=f'Demand on {day_of_week}',
        labels={'trip_count': 'Trip Count', 'avg_earning': 'Average Earning ($)', 'zone': 'Zone'}
    )
    fig.write_image(filename)
    return filename

def train_demand_prediction_model():
    # Prepare data for machine learning
    data['day_of_week'] = pd.to_datetime(data['tpep_pickup_datetime']).dt.dayofweek
    features = data[['pickup_hour', 'day_of_week', 'zone_latitude', 'zone_longitude']]
    target = data['fare_amount']

    X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

    # Train a Random Forest Regressor
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)
    return model

model = train_demand_prediction_model()

@app.get("/weekly-demand")
def get_weekly_demand(day: str):
    """
    Get zones with highest demand for a specific day of the week.
    day: Day of the week (e.g., "Monday", "Tuesday", etc.).
    """
    try:
        if day not in data['pickup_day'].unique():
            return {"status": "error", "message": "Invalid day of the week."}

        demand_data = calculate_weekly_demand(day)
        return {"status": "success", "data": demand_data.to_dict(orient='records')}
    except Exception as e:
        return {"status": "error", "message": str(e)}

@app.get("/weekly-demand/chart")
def get_weekly_demand_chart(day: str):
    """
    Get a chart of weekly demand for a specific day of the week.
    day: Day of the week (e.g., "Monday", "Tuesday", etc.).
    """
    try:
        if day not in data['pickup_day'].unique():
            return {"status": "error", "message": "Invalid day of the week."}

        chart_file = generate_demand_chart(day)
        return FileResponse(chart_file, media_type='image/png', filename='demand_chart.png')
    except Exception as e:
        return {"status": "error", "message": str(e)}

@app.get("/predict")
def predict_demand(pickup_hour: int, day_of_week: int, zone: str):
    """
    Predict demand based on input features.
    pickup_hour: Hour of the day (0-23).
    day_of_week: Day of the week (0=Monday, 6=Sunday).
    zone: Name of the zone.
    """
    try:
        # Get latitude and longitude for the zone
        zone_data = data[data['zone'] == zone].iloc[0]
        latitude = zone_data['zone_latitude']
        longitude = zone_data['zone_longitude']

        # Predict demand
        prediction = model.predict([[pickup_hour, day_of_week, latitude, longitude]])
        return {"status": "success", "predicted_fare": prediction[0]}
    except Exception as e:
        return {"status": "error", "message": str(e)}
# Out:
# C:\Users\jerom\AppData\Local\Temp\ipykernel_21932\1504092631.py:13: DtypeWarning:
#
# Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
get_weekly_demand("Sunday")
# Out:
# {'status': 'success',
#  'data': [{'zone': 'JFK Airport',
#    'peak_hour': 21,
#    'avg_earning': 59.07271057565447,
#    'avg_distance': 15.539489271578363,
#    'trip_count': 28802,
#    'maps_url': 'https://www.google.com/maps?q=40.90406018978221,-73.98946405903479'},
#   {'zone': 'LaGuardia Airport',
#    'peak_hour': 21,
#    'avg_earning': 40.8711628875796,
#    'avg_distance': 9.389827411771707,
#    'trip_count': 16803,
#    'maps_url': 'https://www.google.com/maps?q=40.769671120957824,-73.53104754894086'},
#   {'zone': 'East Village',
#    'peak_hour': 1,
#    'avg_earning': 15.267882520978397,
#    'avg_distance': 2.564434922335297,
#    'trip_count': 16803,
#    'maps_url': 'https://www.google.com/maps?q=40.91436875457597,-74.08333419899034'},
#   {'zone': 'Upper East Side South',
#    'peak_hour': 14,
#    'avg_earning': 14.088041857259226,
#    'avg_distance': 2.0446738517450966,
#    'trip_count': 15959,
#    'maps_url': 'https://www.google.com/maps?q=40.82481644952361,-74.00010353638103'},
#   {'zone': 'Times Sq/Theatre District',
#    'peak_hour': 17,
#    'avg_earning': 22.08160977954811,
#    'avg_distance': 4.012424970812444,
#    'trip_count': 14561,
#    'maps_url': 'https://www.google.com/maps?q=40.84594759884634,-74.25495737945452'},
#   {'zone': 'Penn Station/Madison Sq West',
#    'peak_hour': 20,
#    'avg_earning': 17.929024321664556,
#    'avg_distance': 2.595486433291157,
#    'trip_count': 14226,
#    'maps_url': 'https://www.google.com/maps?q=40.593259255199925,-73.79453023026416'},
#   {'zone': 'Upper East Side North',
#    'peak_hour': 12,
#    'avg_earning': 13.914351905731744,
#    'avg_distance': 2.134816700610998,
#    'trip_count': 13748,
#    'maps_url': 'https://www.google.com/maps?q=40.87324570255901,-73.53026196122036'},
#   {'zone': 'West Village',
#    'peak_hour': 0,
#    'avg_earning': 15.154222222222224,
#    'avg_distance': 2.375855009107468,
#    'trip_count': 13725,
#    'maps_url': 'https://www.google.com/maps?q=40.89740565177083,-73.85691657247894'},
#   {'zone': 'Lincoln Square East',
#    'peak_hour': 18,
#    'avg_earning': 15.35774519638861,
#    'avg_distance': 2.3774774288139517,
#    'trip_count': 12959,
#    'maps_url': 'https://www.google.com/maps?q=40.55502596226384,-74.21937759889805'},
#   {'zone': 'Midtown Center',
#    'peak_hour': 18,
#    'avg_earning': 18.19454573739888,
#    'avg_distance': 3.0441148102053517,
#    'trip_count': 12856,
#    'maps_url': 'https://www.google.com/maps?q=40.74862425294619,-73.65453220858619'},
#   {'zone': 'East Chelsea',
#    'peak_hour': 14,
#    'avg_earning': 17.710508182601206,
#    'avg_distance': 2.651598152063268,
#    'trip_count': 12771,
#    'maps_url': 'https://www.google.com/maps?q=40.88756641168056,-73.8016876193448'},
#   {'zone': 'Clinton East',
#    'peak_hour': 0,
#    'avg_earning': 16.86820341676599,
#    'avg_distance': 2.7362463249900677,
#    'trip_count': 12585,
#    'maps_url': 'https://www.google.com/maps?q=40.53252579649264,-73.66336586445112'},
#   {'zone': 'Midtown East',
#    'peak_hour': 18,
#    'avg_earning': 16.991293364477894,
#    'avg_distance': 2.7009931654987454,
#    'trip_count': 11559,
#    'maps_url': 'https://www.google.com/maps?q=40.65043915490838,-73.50759588639946'},
#   {'zone': 'Upper West Side South',
#    'peak_hour': 13,
#    'avg_earning': 15.466537589394733,
#    'avg_distance': 2.41636926565498,
#    'trip_count': 11466,
#    'maps_url': 'https://www.google.com/maps?q=40.828806446150175,-73.60512069744843'},
#   {'zone': 'Murray Hill',
#    'peak_hour': 11,
#    'avg_earning': 16.285985709050934,
#    'avg_distance': 2.606131366801026,
#    'trip_count': 10916,
#    'maps_url': 'https://www.google.com/maps?q=40.61978094533349,-73.6993031457668'},
#   {'zone': 'Union Sq',
#    'peak_hour': 0,
#    'avg_earning': 14.654989803485353,
#    'avg_distance': 2.2640266963292546,
#    'trip_count': 10788,
#    'maps_url': 'https://www.google.com/maps?q=40.6186245437484,-73.70316409658766'},
#   {'zone': 'Midtown North',
#    'peak_hour': 18,
#    'avg_earning': 19.28799207135778,
#    'avg_distance': 3.228474727452924,
#    'trip_count': 10090,
#    'maps_url': 'https://www.google.com/maps?q=40.64242024718873,-73.96990585847085'},
#   {'zone': 'Greenwich Village South',
#    'peak_hour': 1,
#    'avg_earning': 15.035749496981891,
#    'avg_distance': 2.385271629778672,
#    'trip_count': 9940,
#    'maps_url': 'https://www.google.com/maps?q=40.7468977981822,-74.16143850407198'},
#   {'zone': 'Midtown South',
#    'peak_hour': 0,
#    'avg_earning': 17.614078355155485,
#    'avg_distance': 2.891060761047463,
#    'trip_count': 9776,
#    'maps_url': 'https://www.google.com/maps?q=40.51844347367727,-74.00238553136577'},
#   {'zone': 'Lower East Side',
#    'peak_hour': 1,
#    'avg_earning': 17.45551435156086,
#    'avg_distance': 3.0539692017598994,
#    'trip_count': 9546,
#    'maps_url': 'https://www.google.com/maps?q=40.75537365128879,-73.62409975122443'},
#   {'zone': 'Gramercy',
#    'peak_hour': 0,
#    'avg_earning': 14.3447218028898,
#    'avg_distance': 2.330016174250593,
#    'trip_count': 9274,
#    'maps_url': 'https://www.google.com/maps?q=40.94360637128816,-74.26741695814482'},
#   {'zone': 'Lenox Hill West',
#    'peak_hour': 13,
#    'avg_earning': 13.356684692638781,
#    'avg_distance': 2.07123054850458,
#    'trip_count': 9061,
#    'maps_url': 'https://www.google.com/maps?q=40.65900173748593,-74.24451095929986'},
#   {'zone': 'Flatiron',
#    'peak_hour': 0,
#    'avg_earning': 15.131252186953262,
#    'avg_distance': 2.3554186453386654,
#    'trip_count': 8002,
#    'maps_url': 'https://www.google.com/maps?q=40.90773071422742,-73.8606186682351'},
#   {'zone': 'Yorkville West',
#    'peak_hour': 12,
#    'avg_earning': 13.95239498432602,
#    'avg_distance': 2.3796990595611285,
#    'trip_count': 7975,
#    'maps_url': 'https://www.google.com/maps?q=40.50772830826443,-73.80389392175877'},
#   {'zone': 'West Chelsea/Hudson Yards',
#    'peak_hour': 16,
#    'avg_earning': 16.817660104986878,
#    'avg_distance': 2.48047375328084,
#    'trip_count': 7620,
#    'maps_url': 'https://www.google.com/maps?q=40.69654886233338,-73.87783911273097'},
#   {'zone': 'Upper West Side North',
#    'peak_hour': 13,
#    'avg_earning': 14.65282153676673,
#    'avg_distance': 2.365863398512807,
#    'trip_count': 7262,
#    'maps_url': 'https://www.google.com/maps?q=40.92461170524709,-74.07143033097451'},
#   {'zone': 'Little Italy/NoLiTa',
#    'peak_hour': 1,
#    'avg_earning': 16.092642559109876,
#    'avg_distance': 2.5925966620305982,
#    'trip_count': 7190,
#    'maps_url': 'https://www.google.com/maps?q=40.71355389431313,-74.22444563139526'},
#   {'zone': 'Greenwich Village North',
#    'peak_hour': 1,
#    'avg_earning': 14.39725208913649,
#    'avg_distance': 2.205050139275766,
#    'trip_count': 7180,
#    'maps_url': 'https://www.google.com/maps?q=40.88548358997728,-73.92122258337555'},
#   {'zone': 'Sutton Place/Turtle Bay North',
#    'peak_hour': 13,
#    'avg_earning': 14.550153502235469,
#    'avg_distance': 2.2902131147540983,
#    'trip_count': 6710,
#    'maps_url': 'https://www.google.com/maps?q=40.77436689468329,-73.9250714864047'},
#   {'zone': 'Central Park',
#    'peak_hour': 14,
#    'avg_earning': 16.822640183346063,
#    'avg_distance': 2.4404003055767762,
#    'trip_count': 6545,
#    'maps_url': 'https://www.google.com/maps?q=40.757117219206805,-73.89092608091124'},
#   {'zone': 'Meatpacking/West Village West',
#    'peak_hour': 1,
#    'avg_earning': 16.835431578947368,
#    'avg_distance': 2.7442024291497975,
#    'trip_count': 6175,
#    'maps_url': 'https://www.google.com/maps?q=40.98589104136048,-74.07437234194295'},
#   {'zone': 'Garment District',
#    'peak_hour': 0,
#    'avg_earning': 18.47069969356486,
#    'avg_distance': 2.9783469526727955,
#    'trip_count': 5874,
#    'maps_url': 'https://www.google.com/maps?q=40.531779175143015,-74.01522185707898'},
#   {'zone': 'TriBeCa/Civic Center',
#    'peak_hour': 0,
#    'avg_earning': 17.92203002269157,
#    'avg_distance': 2.9895322045732238,
#    'trip_count': 5729,
#    'maps_url': 'https://www.google.com/maps?q=40.8259806297513,-74.20494566698554'},
#   {'zone': 'Lenox Hill East',
#    'peak_hour': 13,
#    'avg_earning': 14.100692087702575,
#    'avg_distance': 2.380446139180172,
#    'trip_count': 5245,
#    'maps_url': 'https://www.google.com/maps?q=40.94804564996175,-74.14336709216856'},
#   {'zone': 'SoHo',
#    'peak_hour': 1,
#    'avg_earning': 16.51093152866242,
#    'avg_distance': 2.651142515923567,
#    'trip_count': 5024,
#    'maps_url': 'https://www.google.com/maps?q=40.95020902858167,-74.23492097548647'},
#   {'zone': 'Yorkville East',
#    'peak_hour': 12,
#    'avg_earning': 15.086433041301627,
#    'avg_distance': 2.647841051314143,
#    'trip_count': 4794,
#    'maps_url': 'https://www.google.com/maps?q=40.68507935012772,-73.93547459777143'},
#   {'zone': 'UN/Turtle Bay South',
#    'peak_hour': 11,
#    'avg_earning': 18.311485337866554,
#    'avg_distance': 3.134218019549511,
#    'trip_count': 4706,
#    'maps_url': 'https://www.google.com/maps?q=40.85608961067377,-73.78063175830715'},
#   {'zone': 'Lincoln Square West',
#    'peak_hour': 12,
#    'avg_earning': 14.108120775123929,
#    'avg_distance': 2.220955385308698,
#    'trip_count': 4438,
#    'maps_url': 'https://www.google.com/maps?q=40.61396758127097,-74.28542253947876'},
#   {'zone': 'Kips Bay',
#    'peak_hour': 0,
#    'avg_earning': 13.894097932018065,
#    'avg_distance': 2.2956429759923935,
#    'trip_count': 4207,
#    'maps_url': 'https://www.google.com/maps?q=40.94627949924499,-73.99111788975938'},
#   {'zone': 'Clinton West',
#    'peak_hour': 9,
#    'avg_earning': 19.861166574738004,
#    'avg_distance': 3.6842415885273025,
#    'trip_count': 3626,
#    'maps_url': 'https://www.google.com/maps?q=40.98281601653728,-74.02960387451877'},
#   {'zone': 'Manhattan Valley',
#    'peak_hour': 12,
#    'avg_earning': 15.057521998296906,
#    'avg_distance': 23.924200965086573,
#    'trip_count': 3523,
#    'maps_url': 'https://www.google.com/maps?q=40.55993268366685,-74.07451618018128'},
#   {'zone': 'Financial District North',
#    'peak_hour': 0,
#    'avg_earning': 22.160862068965518,
#    'avg_distance': 4.2390095377843,
#    'trip_count': 2726,
#    'maps_url': 'https://www.google.com/maps?q=40.88612238464833,-74.16136454394332'},
#   {'zone': 'Hudson Sq',
#    'peak_hour': 0,
#    'avg_earning': 16.519886274509805,
#    'avg_distance': 2.7257176470588234,
#    'trip_count': 2550,
#    'maps_url': 'https://www.google.com/maps?q=40.70519146151781,-74.16965245833485'},
#   {'zone': 'World Trade Center',
#    'peak_hour': 14,
#    'avg_earning': 22.013813861386136,
#    'avg_distance': 4.130285148514851,
#    'trip_count': 2525,
#    'maps_url': 'https://www.google.com/maps?q=40.95743219511022,-73.58778897288727'},
#   {'zone': 'East Harlem South',
#    'peak_hour': 13,
#    'avg_earning': 14.983876739562623,
#    'avg_distance': 2.615546719681909,
#    'trip_count': 2515,
#    'maps_url': 'https://www.google.com/maps?q=40.52261364445527,-73.51931833642998'},
#   {'zone': 'Morningside Heights',
#    'peak_hour': 13,
#    'avg_earning': 18.021645822911456,
#    'avg_distance': 3.11128064032016,
#    'trip_count': 1999,
#    'maps_url': 'https://www.google.com/maps?q=40.75133951161443,-74.02735716779759'},
#   {'zone': 'Battery Park City',
#    'peak_hour': 13,
#    'avg_earning': 22.16656926952141,
#    'avg_distance': 4.309239294710328,
#    'trip_count': 1985,
#    'maps_url': 'https://www.google.com/maps?q=40.7115,-74.0156'},
#   {'zone': 'East Elmhurst',
#    'peak_hour': 22,
#    'avg_earning': 39.60122427983539,
#    'avg_distance': 9.155622427983538,
#    'trip_count': 1944,
#    'maps_url': 'https://www.google.com/maps?q=40.947413675213824,-74.25865462306511'},
#   {'zone': 'Alphabet City',
#    'peak_hour': 1,
#    'avg_earning': 16.61683241252302,
#    'avg_distance': 2.8420626151012893,
#    'trip_count': 1629,
#    'maps_url': 'https://www.google.com/maps?q=40.7254,-73.9793'},
#   {'zone': 'Central Harlem',
#    'peak_hour': 13,
#    'avg_earning': 16.337068245125348,
#    'avg_distance': 2.857506963788301,
#    'trip_count': 1436,
#    'maps_url': 'https://www.google.com/maps?q=40.8925879806965,-73.60634214513591'},
#   {'zone': 'Financial District South',
#    'peak_hour': 0,
#    'avg_earning': 22.595378681626926,
#    'avg_distance': 4.500364656381487,
#    'trip_count': 1426,
#    'maps_url': 'https://www.google.com/maps?q=40.59935784076709,-74.17485036586312'},
#   {'zone': 'East Harlem North',
#    'peak_hour': 13,
#    'avg_earning': 16.070931768158474,
#    'avg_distance': 2.8104842259721203,
#    'trip_count': 1363,
#    'maps_url': 'https://www.google.com/maps?q=40.59799143120957,-73.71912693302187'},
#   {'zone': 'NV',
#    'peak_hour': 18,
#    'avg_earning': 23.376867378048782,
#    'avg_distance': 4.171135670731707,
#    'trip_count': 1312,
#    'maps_url': 'https://www.google.com/maps?q=40.96415928129386,-74.07809505361509'},
#   {'zone': 'Seaport',
#    'peak_hour': 0,
#    'avg_earning': 20.572862870890138,
#    'avg_distance': 3.9274979951884523,
#    'trip_count': 1247,
#    'maps_url': 'https://www.google.com/maps?q=40.54655138390295,-73.64251195256772'},
#   {'zone': 'Bloomingdale',
#    'peak_hour': 14,
#    'avg_earning': 15.915603944124898,
#    'avg_distance': 2.6071980279375513,
#    'trip_count': 1217,
#    'maps_url': 'https://www.google.com/maps?q=40.8005575058716,-73.85455899003333'},
#   {'zone': 'Williamsburg (North Side)',
#    'peak_hour': 0,
#    'avg_earning': 23.216823308270676,
#    'avg_distance': 4.475667293233083,
#    'trip_count': 1064,
#    'maps_url': 'https://www.google.com/maps?q=40.64038618122043,-73.79795353593275'},
#   {'zone': 'Two Bridges/Seward Park',
#    'peak_hour': 0,
#    'avg_earning': 20.24447592067989,
#    'avg_distance': 3.518328611898017,
#    'trip_count': 1059,
#    'maps_url': 'https://www.google.com/maps?q=40.61213465473028,-74.20597900257832'},
#   {'zone': 'Stuy Town/Peter Cooper Village',
#    'peak_hour': 12,
#    'avg_earning': 16.15943396226415,
#    'avg_distance': 2.623274139844617,
#    'trip_count': 901,
#    'maps_url': 'https://www.google.com/maps?q=40.50459852580831,-73.96062239260242'},
#   {'zone': 'Chinatown',
#    'peak_hour': 1,
#    'avg_earning': 19.936753393665157,
#    'avg_distance': 3.567477375565611,
#    'trip_count': 884,
#    'maps_url': 'https://www.google.com/maps?q=40.52322520636,-73.66136385682658'},
#   {'zone': 'East Williamsburg',
#    'peak_hour': 3,
#    'avg_earning': 27.2319350473613,
#    'avg_distance': 5.228146143437077,
#    'trip_count': 739,
#    'maps_url': 'https://www.google.com/maps?q=40.6783766633468,-73.9488228634355'},
#   {'zone': 'Williamsburg (South Side)',
#    'peak_hour': 0,
#    'avg_earning': 23.495481171548114,
#    'avg_distance': 4.504769874476987,
#    'trip_count': 717,
#    'maps_url': 'https://www.google.com/maps?q=40.51215798321573,-73.83254855046152'},
#   {'zone': 'Central Harlem North',
#    'peak_hour': 13,
#    'avg_earning': 19.528423423423423,
#    'avg_distance': 3.4816366366366367,
#    'trip_count': 666,
#    'maps_url': 'https://www.google.com/maps?q=40.59983689107918,-73.56940755795482'},
#   {'zone': 'Long Island City/Hunters Point',
#    'peak_hour': 23,
#    'avg_earning': 27.36746815286624,
#    'avg_distance': 4.517786624203822,
#    'trip_count': 628,
#    'maps_url': 'https://www.google.com/maps?q=40.90900738296125,-73.75359458126691'},
#   {'zone': 'Downtown Brooklyn/MetroTech',
#    'peak_hour': 0,
#    'avg_earning': 23.89336936936937,
#    'avg_distance': 4.759711711711711,
#    'trip_count': 555,
#    'maps_url': 'https://www.google.com/maps?q=40.77335513967164,-73.88220539195615'},
#   {'zone': 'Greenpoint',
#    'peak_hour': 0,
#    'avg_earning': 24.246189591078068,
#    'avg_distance': 91.64241635687733,
#    'trip_count': 538,
#    'maps_url': 'https://www.google.com/maps?q=40.78063859878475,-73.90670729990653'},
#   {'zone': 'Sunnyside',
#    'peak_hour': 16,
#    'avg_earning': 30.38729007633588,
#    'avg_distance': 5.129790076335878,
#    'trip_count': 524,
#    'maps_url': 'https://www.google.com/maps?q=40.831750884554026,-74.21104201415508'},
#   {'zone': 'Hamilton Heights',
#    'peak_hour': 9,
#    'avg_earning': 20.12924335378323,
#    'avg_distance': 3.9575460122699386,
#    'trip_count': 489,
#    'maps_url': 'https://www.google.com/maps?q=40.71377050917928,-73.9811962124821'},
#   {'zone': 'Astoria',
#    'peak_hour': 0,
#    'avg_earning': 21.59832285115304,
#    'avg_distance': 4.737735849056604,
#    'trip_count': 477,
#    'maps_url': 'https://www.google.com/maps?q=40.7644,-73.9235'},
#   {'zone': 'Fort Greene',
#    'peak_hour': 23,
#    'avg_earning': 25.339821826280623,
#    'avg_distance': 5.299777282850779,
#    'trip_count': 449,
#    'maps_url': 'https://www.google.com/maps?q=40.9315517129378,-73.81062340301251'},
#   {'zone': 'Boerum Hill',
#    'peak_hour': 0,
#    'avg_earning': 22.459290617848968,
#    'avg_distance': 4.391945080091533,
#    'trip_count': 437,
#    'maps_url': 'https://www.google.com/maps?q=40.85403628889802,-73.55107618067137'},
#   {'zone': 'Brooklyn Heights',
#    'peak_hour': 18,
#    'avg_earning': 23.764745370370374,
#    'avg_distance': 4.811782407407407,
#    'trip_count': 432,
#    'maps_url': 'https://www.google.com/maps?q=40.76237821581612,-73.59810154245764'},
#   {'zone': 'DUMBO/Vinegar Hill',
#    'peak_hour': 18,
#    'avg_earning': 26.04527315914489,
#    'avg_distance': 5.603206650831353,
#    'trip_count': 421,
#    'maps_url': 'https://www.google.com/maps?q=40.59242722776276,-73.68400515752111'},
#   {'zone': 'Manhattanville',
#    'peak_hour': 17,
#    'avg_earning': 16.080956937799044,
#    'avg_distance': 3.178851674641148,
#    'trip_count': 418,
#    'maps_url': 'https://www.google.com/maps?q=40.668807585701806,-74.20546813790267'},
#   {'zone': 'Bushwick South',
#    'peak_hour': 2,
#    'avg_earning': 26.199203084832906,
#    'avg_distance': 5.220565552699228,
#    'trip_count': 389,
#    'maps_url': 'https://www.google.com/maps?q=40.56974693032602,-74.0124070790242'},
#   {'zone': 'Crown Heights North',
#    'peak_hour': 9,
#    'avg_earning': 25.733856749311293,
#    'avg_distance': 5.0493112947658405,
#    'trip_count': 363,
#    'maps_url': 'https://www.google.com/maps?q=40.62938999080001,-74.27012144900063'},
#   {'zone': 'Washington Heights South',
#    'peak_hour': 14,
#    'avg_earning': 23.319222222222223,
#    'avg_distance': 4.9733888888888895,
#    'trip_count': 360,
#    'maps_url': 'https://www.google.com/maps?q=40.62199482168954,-74.26547207043954'},
#   {'zone': 'Red Hook',
#    'peak_hour': 9,
#    'avg_earning': 42.864565826330534,
#    'avg_distance': 10.202156862745099,
#    'trip_count': 357,
#    'maps_url': 'https://www.google.com/maps?q=40.84546886905123,-73.90446375623793'},
#   {'zone': 'Bushwick North',
#    'peak_hour': 3,
#    'avg_earning': 28.654810495626823,
#    'avg_distance': 5.255043731778426,
#    'trip_count': 343,
#    'maps_url': 'https://www.google.com/maps?q=40.80592644736119,-73.73801273281032'},
#   {'zone': 'Jackson Heights',
#    'peak_hour': 4,
#    'avg_earning': 28.789467455621303,
#    'avg_distance': 3.945710059171598,
#    'trip_count': 338,
#    'maps_url': 'https://www.google.com/maps?q=40.64487572645688,-73.83137953498122'},
#   {'zone': 'South Ozone Park',
#    'peak_hour': 23,
#    'avg_earning': 49.495225806451614,
#    'avg_distance': 4.651870967741935,
#    'trip_count': 310,
#    'maps_url': 'https://www.google.com/maps?q=40.94855512997629,-73.649760346194'},
#   {'zone': 'Park Slope',
#    'peak_hour': 0,
#    'avg_earning': 24.694473684210525,
#    'avg_distance': 4.845131578947369,
#    'trip_count': 304,
#    'maps_url': 'https://www.google.com/maps?q=40.81676485538045,-74.22697065857109'},
#   {'zone': 'Long Island City/Queens Plaza',
#    'peak_hour': 0,
#    'avg_earning': 22.650099009900988,
#    'avg_distance': 4.2141914191419145,
#    'trip_count': 303,
#    'maps_url': 'https://www.google.com/maps?q=40.93036529162817,-74.24304908123182'},
#   {'zone': 'Maspeth',
#    'peak_hour': 4,
#    'avg_earning': 33.02707746478873,
#    'avg_distance': 6.191373239436619,
#    'trip_count': 284,
#    'maps_url': 'https://www.google.com/maps?q=40.681814801189645,-73.65721525569212'},
#   {'zone': 'Clinton Hill',
#    'peak_hour': 0,
#    'avg_earning': 24.351056910569103,
#    'avg_distance': 268.01520325203256,
#    'trip_count': 246,
#    'maps_url': 'https://www.google.com/maps?q=40.974442768626666,-73.58799572654594'},
#   {'zone': 'East New York',
#    'peak_hour': 9,
#    'avg_earning': 25.765819672131148,
#    'avg_distance': 5.3344672131147535,
#    'trip_count': 244,
#    'maps_url': 'https://www.google.com/maps?q=40.66266516538163,-73.88695972135905'},
#   {'zone': 'Bedford',
#    'peak_hour': 0,
#    'avg_earning': 25.707860082304528,
#    'avg_distance': 4.912139917695473,
#    'trip_count': 243,
#    'maps_url': 'https://www.google.com/maps?q=40.97535715320496,-73.5291040183286'},
#   {'zone': 'Stuyvesant Heights',
#    'peak_hour': 9,
#    'avg_earning': 26.816329113924052,
#    'avg_distance': 4.917721518987341,
#    'trip_count': 237,
#    'maps_url': 'https://www.google.com/maps?q=40.550735771433025,-73.57491649192421'},
#   {'zone': 'Jamaica',
#    'peak_hour': 23,
#    'avg_earning': 37.15152173913044,
#    'avg_distance': 8.823173913043478,
#    'trip_count': 230,
#    'maps_url': 'https://www.google.com/maps?q=40.58061064362701,-73.54781580686003'},
#   {'zone': 'Prospect-Lefferts Gardens',
#    'peak_hour': 8,
#    'avg_earning': 26.90190909090909,
#    'avg_distance': 5.1181363636363635,
#    'trip_count': 220,
#    'maps_url': 'https://www.google.com/maps?q=40.79544647159412,-74.06543138264155'},
#   {'zone': 'Steinway',
#    'peak_hour': 0,
#    'avg_earning': 31.130480769230772,
#    'avg_distance': 5.349038461538461,
#    'trip_count': 208,
#    'maps_url': 'https://www.google.com/maps?q=40.8032145298298,-73.85327660021136'},
#   {'zone': 'Baisley Park',
#    'peak_hour': 22,
#    'avg_earning': 55.237355769230774,
#    'avg_distance': 11.639663461538463,
#    'trip_count': 208,
#    'maps_url': 'https://www.google.com/maps?q=40.67640000000001,-73.7854'},
#   {'zone': 'Battery Park',
#    'peak_hour': 16,
#    'avg_earning': 22.96116161616162,
#    'avg_distance': 3.923989898989899,
#    'trip_count': 198,
#    'maps_url': 'https://www.google.com/maps?q=40.7033,-74.017'},
#   {'zone': 'Elmhurst',
#    'peak_hour': 21,
#    'avg_earning': 28.287551020408163,
#    'avg_distance': 5.051479591836735,
#    'trip_count': 196,
#    'maps_url': 'https://www.google.com/maps?q=40.77134804157912,-74.27971940526763'},
#   {'zone': 'Sunset Park West',
#    'peak_hour': 5,
#    'avg_earning': 33.211948717948715,
#    'avg_distance': 7.438205128205128,
#    'trip_count': 195,
#    'maps_url': 'https://www.google.com/maps?q=40.58040402570875,-74.29091708418606'},
#   {'zone': 'Woodside',
#    'peak_hour': 3,
#    'avg_earning': 23.699278350515463,
#    'avg_distance': 4.085515463917526,
#    'trip_count': 194,
#    'maps_url': 'https://www.google.com/maps?q=40.97696428850129,-73.53967081273875'},
#   {'zone': 'Queensbridge/Ravenswood',
#    'peak_hour': 9,
#    'avg_earning': 13.410052631578946,
#    'avg_distance': 2.3671052631578946,
#    'trip_count': 190,
#    'maps_url': 'https://www.google.com/maps?q=40.82258639520472,-73.66830548576435'},
#   {'zone': 'Mott Haven/Port Morris',
#    'peak_hour': 6,
#    'avg_earning': 25.374338624338623,
#    'avg_distance': 5.389788359788359,
#    'trip_count': 189,
#    'maps_url': 'https://www.google.com/maps?q=40.63932323211831,-73.6132697985256'},
#   {'zone': 'Corona',
#    'peak_hour': 7,
#    'avg_earning': 37.28158536585366,
#    'avg_distance': 6.629268292682927,
#    'trip_count': 164,
#    'maps_url': 'https://www.google.com/maps?q=40.56101911742239,-73.86588429223394'},
#   {'zone': 'Canarsie',
#    'peak_hour': 8,
#    'avg_earning': 26.69042944785276,
#    'avg_distance': 5.804846625766872,
#    'trip_count': 163,
#    'maps_url': 'https://www.google.com/maps?q=40.68318092164685,-73.65251107561718'},
#   {'zone': 'Flushing Meadows-Corona Park',
#    'peak_hour': 7,
#    'avg_earning': 50.1087037037037,
#    'avg_distance': 8.924506172839505,
#    'trip_count': 162,
#    'maps_url': 'https://www.google.com/maps?q=40.885635173342976,-74.07605288244325'},
#   {'zone': 'Richmond Hill',
#    'peak_hour': 23,
#    'avg_earning': 39.582187499999996,
#    'avg_distance': 428.3880625,
#    'trip_count': 160,
#    'maps_url': 'https://www.google.com/maps?q=40.968364994368365,-73.86037689414101'},
#   {'zone': 'Ridgewood',
#    'peak_hour': 2,
#    'avg_earning': 25.725471698113207,
#    'avg_distance': 5.594591194968554,
#    'trip_count': 159,
#    'maps_url': 'https://www.google.com/maps?q=40.568760472073,-73.9467755989013'},
#   {'zone': 'Flatbush/Ditmas Park',
#    'peak_hour': 10,
#    'avg_earning': 25.166942675159238,
#    'avg_distance': 4.991783439490446,
#    'trip_count': 157,
#    'maps_url': 'https://www.google.com/maps?q=40.5027610585618,-74.09980568146833'},
#   {'zone': 'Old Astoria',
#    'peak_hour': 8,
#    'avg_earning': 23.279871794871795,
#    'avg_distance': 5.03051282051282,
#    'trip_count': 156,
#    'maps_url': 'https://www.google.com/maps?q=40.68389156635963,-74.29132987881576'},
#   {'zone': 'Brownsville',
#    'peak_hour': 11,
#    'avg_earning': 23.546711409395975,
#    'avg_distance': 4.515973154362416,
#    'trip_count': 149,
#    'maps_url': 'https://www.google.com/maps?q=40.64561457009902,-73.74238740720378'},
#   {'zone': 'South Jamaica',
#    'peak_hour': 13,
#    'avg_earning': 41.607191780821914,
#    'avg_distance': 9.510205479452054,
#    'trip_count': 146,
#    'maps_url': 'https://www.google.com/maps?q=40.86297783943512,-74.00348628234649'},
#   {'zone': 'Forest Hills',
#    'peak_hour': 0,
#    'avg_earning': 25.039375,
#    'avg_distance': 5.686597222222222,
#    'trip_count': 144,
#    'maps_url': 'https://www.google.com/maps?q=40.67923286427214,-73.70968246664339'},
#   {'zone': 'Ocean Hill',
#    'peak_hour': 14,
#    'avg_earning': 26.46078014184397,
#    'avg_distance': 4.953971631205674,
#    'trip_count': 141,
#    'maps_url': 'https://www.google.com/maps?q=40.6188187719962,-73.58358141720304'},
#   {'zone': 'Washington Heights North',
#    'peak_hour': 14,
#    'avg_earning': 26.16888888888889,
#    'avg_distance': 6.030518518518519,
#    'trip_count': 135,
#    'maps_url': 'https://www.google.com/maps?q=40.63260118384086,-73.52409693863389'},
#   {'zone': 'Brooklyn Navy Yard',
#    'peak_hour': 4,
#    'avg_earning': 29.70469696969697,
#    'avg_distance': 5.466060606060606,
#    'trip_count': 132,
#    'maps_url': 'https://www.google.com/maps?q=40.715972509321055,-73.70738510579663'},
#   {'zone': 'Prospect Heights',
#    'peak_hour': 0,
#    'avg_earning': 24.749922480620157,
#    'avg_distance': 4.790542635658915,
#    'trip_count': 129,
#    'maps_url': 'https://www.google.com/maps?q=40.83878218092114,-74.03706836370407'},
#   {'zone': 'East Flatbush/Farragut',
#    'peak_hour': 10,
#    'avg_earning': 25.972845528455284,
#    'avg_distance': 4.059349593495935,
#    'trip_count': 123,
#    'maps_url': 'https://www.google.com/maps?q=40.79894998940554,-73.87491629474547'},
#   {'zone': 'Crown Heights South',
#    'peak_hour': 12,
#    'avg_earning': 24.4830081300813,
#    'avg_distance': 635.0919512195121,
#    'trip_count': 123,
#    'maps_url': 'https://www.google.com/maps?q=40.83126114217699,-73.64191955147227'},
#   {'zone': 'East Flatbush/Remsen Village',
#    'peak_hour': 10,
#    'avg_earning': 24.21864406779661,
#    'avg_distance': 5.577372881355932,
#    'trip_count': 118,
#    'maps_url': 'https://www.google.com/maps?q=40.96093711751156,-73.86749190271192'},
#   {'zone': 'Carroll Gardens',
#    'peak_hour': 0,
#    'avg_earning': 23.40742268041237,
#    'avg_distance': 4.419484536082474,
#    'trip_count': 97,
#    'maps_url': 'https://www.google.com/maps?q=40.72803499210852,-73.65190928425666'},
#   {'zone': 'Newark Airport',
#    'peak_hour': 17,
#    'avg_earning': 84.27917525773196,
#    'avg_distance': 1.714639175257732,
#    'trip_count': 97,
#    'maps_url': 'https://www.google.com/maps?q=40.6895,-74.1745'},
#   {'zone': 'Kew Gardens',
#    'peak_hour': 15,
#    'avg_earning': 52.755744680851066,
#    'avg_distance': 5.485744680851064,
#    'trip_count': 94,
#    'maps_url': 'https://www.google.com/maps?q=40.93573029509386,-73.93339768760679'},
#   {'zone': 'Cobble Hill',
#    'peak_hour': 19,
#    'avg_earning': 21.890333333333334,
#    'avg_distance': 4.610666666666666,
#    'trip_count': 90,
#    'maps_url': 'https://www.google.com/maps?q=40.652306884586686,-74.2248144481273'},
#   {'zone': 'Flatlands',
#    'peak_hour': 9,
#    'avg_earning': 23.708555555555556,
#    'avg_distance': 4.892222222222222,
#    'trip_count': 90,
#    'maps_url': 'https://www.google.com/maps?q=40.85342867192381,-73.72832326183995'},
#   {'zone': 'Briarwood/Jamaica Hills',
#    'peak_hour': 8,
#    'avg_earning': 37.00988764044944,
#    'avg_distance': 8.451235955056179,
#    'trip_count': 89,
#    'maps_url': 'https://www.google.com/maps?q=40.91622132040021,-74.22225880498338'},
#   {'zone': 'Springfield Gardens South',
#    'peak_hour': 18,
#    'avg_earning': 60.58955056179776,
#    'avg_distance': 12.17932584269663,
#    'trip_count': 89,
#    'maps_url': 'https://www.google.com/maps?q=40.82101582307715,-73.69729745179285'},
#   {'zone': 'Elmhurst/Maspeth',
#    'peak_hour': 9,
#    'avg_earning': 30.18139534883721,
#    'avg_distance': 4.008139534883721,
#    'trip_count': 86,
#    'maps_url': 'https://www.google.com/maps?q=40.57046211248738,-73.52988126825765'},
#   {'zone': 'East New York/Pennsylvania Avenue',
#    'peak_hour': 8,
#    'avg_earning': 28.52156626506024,
#    'avg_distance': 6.050602409638554,
#    'trip_count': 83,
#    'maps_url': 'https://www.google.com/maps?q=40.69433864484474,-74.04163482164701'},
#   {'zone': 'Starrett City',
#    'peak_hour': 12,
#    'avg_earning': 28.48148148148148,
#    'avg_distance': 6.507283950617285,
#    'trip_count': 81,
#    'maps_url': 'https://www.google.com/maps?q=40.94927709426354,-73.67828246725804'},
#   {'zone': 'East Concourse/Concourse Village',
#    'peak_hour': 9,
#    'avg_earning': 26.74759493670886,
#    'avg_distance': 6.219746835443038,
#    'trip_count': 79,
#    'maps_url': 'https://www.google.com/maps?q=40.9697494707821,-74.23172202800498'},
#   {'zone': 'Rego Park',
#    'peak_hour': 18,
#    'avg_earning': 35.341410256410256,
#    'avg_distance': 5.871538461538462,
#    'trip_count': 78,
#    'maps_url': 'https://www.google.com/maps?q=40.69336767315027,-74.25395299198668'},
#   {'zone': 'West Concourse',
#    'peak_hour': 0,
#    'avg_earning': 24.134871794871795,
#    'avg_distance': 4.525384615384616,
#    'trip_count': 78,
#    'maps_url': 'https://www.google.com/maps?q=40.94602327758856,-73.50562816310456'},
#   {'zone': 'Flushing',
#    'peak_hour': 22,
#    'avg_earning': 26.567402597402598,
#    'avg_distance': 6.774155844155844,
#    'trip_count': 77,
#    'maps_url': 'https://www.google.com/maps?q=40.8645035840205,-73.77184209862581'},
#   {'zone': 'Erasmus',
#    'peak_hour': 9,
#    'avg_earning': 24.30584615384615,
#    'avg_distance': 4.829384615384615,
#    'trip_count': 65,
#    'maps_url': 'https://www.google.com/maps?q=40.537275321839886,-73.74322063512504'},
#   {'zone': 'Bay Ridge',
#    'peak_hour': 10,
#    'avg_earning': 22.60890625,
#    'avg_distance': 4.6665624999999995,
#    'trip_count': 64,
#    'maps_url': 'https://www.google.com/maps?q=40.6262,-74.0321'},
#   {'zone': 'Co-Op City',
#    'peak_hour': 9,
#    'avg_earning': 34.67682539682539,
#    'avg_distance': 9.364126984126983,
#    'trip_count': 63,
#    'maps_url': 'https://www.google.com/maps?q=40.90419867405823,-73.99953363788805'},
#   {'zone': 'South Williamsburg',
#    'peak_hour': 15,
#    'avg_earning': 23.835666666666665,
#    'avg_distance': 5.271333333333334,
#    'trip_count': 60,
#    'maps_url': 'https://www.google.com/maps?q=40.94354321213256,-73.5422011380929'},
#   {'zone': 'Melrose South',
#    'peak_hour': 12,
#    'avg_earning': 22.101666666666667,
#    'avg_distance': 4.3365,
#    'trip_count': 60,
#    'maps_url': 'https://www.google.com/maps?q=40.981223647471055,-74.15804836497622'},
#   {'zone': 'University Heights/Morris Heights',
#    'peak_hour': 9,
#    'avg_earning': 27.35298245614035,
#    'avg_distance': 6.4103508771929825,
#    'trip_count': 57,
#    'maps_url': 'https://www.google.com/maps?q=40.662699849079644,-73.83330498792228'},
#   {'zone': 'Soundview/Castle Hill',
#    'peak_hour': 9,
#    'avg_earning': 28.600877192982455,
#    'avg_distance': 6.873333333333333,
#    'trip_count': 57,
#    'maps_url': 'https://www.google.com/maps?q=40.66951489552435,-73.51068833719906'},
#   {'zone': 'Morrisania/Melrose',
#    'peak_hour': 9,
#    'avg_earning': 23.75684210526316,
#    'avg_distance': 4.4571929824561405,
#    'trip_count': 57,
#    'maps_url': 'https://www.google.com/maps?q=40.525739375624994,-73.55539413951715'},
#   {'zone': 'Williamsbridge/Olinville',
#    'peak_hour': 10,
#    'avg_earning': 38.77964285714285,
#    'avg_distance': 294.6798214285714,
#    'trip_count': 56,
#    'maps_url': 'https://www.google.com/maps?q=40.86122605763075,-73.93636714818578'},
#   {'zone': 'Howard Beach',
#    'peak_hour': 22,
#    'avg_earning': 29.465555555555557,
#    'avg_distance': 7.602037037037037,
#    'trip_count': 54,
#    'maps_url': 'https://www.google.com/maps?q=40.62464611457444,-73.77304509470484'},
#   {'zone': 'Inwood',
#    'peak_hour': 4,
#    'avg_earning': 27.009622641509434,
#    'avg_distance': 6.2250943396226415,
#    'trip_count': 53,
#    'maps_url': 'https://www.google.com/maps?q=40.61439908274582,-73.78606457743494'},
#   {'zone': 'Borough Park',
#    'peak_hour': 12,
#    'avg_earning': 21.83490196078431,
#    'avg_distance': 4.522745098039215,
#    'trip_count': 51,
#    'maps_url': 'https://www.google.com/maps?q=40.5102922471479,-73.74317616266002'},
#   {'zone': 'North Corona',
#    'peak_hour': 2,
#    'avg_earning': 21.417199999999998,
#    'avg_distance': 3.8132,
#    'trip_count': 50,
#    'maps_url': 'https://www.google.com/maps?q=40.9928252270553,-73.57795767465635'},
#   {'zone': 'Middle Village',
#    'peak_hour': 1,
#    'avg_earning': 30.31612244897959,
#    'avg_distance': 5.683469387755102,
#    'trip_count': 49,
#    'maps_url': 'https://www.google.com/maps?q=40.62589114791268,-73.69950819868731'},
#   {'zone': 'Woodhaven',
#    'peak_hour': 23,
#    'avg_earning': 24.347083333333334,
#    'avg_distance': 5.034375,
#    'trip_count': 48,
#    'maps_url': 'https://www.google.com/maps?q=40.588555339703525,-74.26364289572683'},
#   {'zone': 'Cypress Hills',
#    'peak_hour': 9,
#    'avg_earning': 27.9768085106383,
#    'avg_distance': 1004.6434042553191,
#    'trip_count': 47,
#    'maps_url': 'https://www.google.com/maps?q=40.65585553804471,-74.01184748687099'},
#   {'zone': 'Saint Albans',
#    'peak_hour': 8,
#    'avg_earning': 37.06,
#    'avg_distance': 9.419777777777778,
#    'trip_count': 45,
#    'maps_url': 'https://www.google.com/maps?q=40.90861110010061,-74.21910185910177'},
#   {'zone': 'Marine Park/Mill Basin',
#    'peak_hour': 15,
#    'avg_earning': 25.01772727272727,
#    'avg_distance': 5.755909090909091,
#    'trip_count': 44,
#    'maps_url': 'https://www.google.com/maps?q=40.75939531087168,-73.59802238917835'},
#   {'zone': 'Kensington',
#    'peak_hour': 6,
#    'avg_earning': 30.56357142857143,
#    'avg_distance': 6.631190476190476,
#    'trip_count': 42,
#    'maps_url': 'https://www.google.com/maps?q=40.81670187825521,-73.78536942524612'},
#   {'zone': 'Glendale',
#    'peak_hour': 22,
#    'avg_earning': 20.826428571428572,
#    'avg_distance': 4.874047619047619,
#    'trip_count': 42,
#    'maps_url': 'https://www.google.com/maps?q=40.66259166101337,-74.2884852090962'},
#   {'zone': 'Gowanus',
#    'peak_hour': 14,
#    'avg_earning': 24.535238095238096,
#    'avg_distance': 4.807857142857143,
#    'trip_count': 42,
#    'maps_url': 'https://www.google.com/maps?q=40.8187787356776,-74.2631978863826'},
#   {'zone': 'Highbridge',
#    'peak_hour': 7,
#    'avg_earning': 29.506341463414635,
#    'avg_distance': 6.868048780487804,
#    'trip_count': 41,
#    'maps_url': 'https://www.google.com/maps?q=40.515714592843366,-74.26375679218236'},
#   {'zone': 'Jamaica Estates',
#    'peak_hour': 8,
#    'avg_earning': 29.122000000000003,
#    'avg_distance': 7.5802499999999995,
#    'trip_count': 40,
#    'maps_url': 'https://www.google.com/maps?q=40.96484882617128,-73.8396206576993'},
#   {'zone': 'Parkchester',
#    'peak_hour': 7,
#    'avg_earning': 29.36842105263158,
#    'avg_distance': 8.634473684210526,
#    'trip_count': 38,
#    'maps_url': 'https://www.google.com/maps?q=40.767887342037376,-74.04454908992767'},
#   {'zone': 'Queens Village',
#    'peak_hour': 15,
#    'avg_earning': 31.936578947368417,
#    'avg_distance': 9.251052631578949,
#    'trip_count': 38,
#    'maps_url': 'https://www.google.com/maps?q=40.75604652914964,-73.69810037644986'},
#   {'zone': 'Randalls Island',
#    'peak_hour': 10,
#    'avg_earning': 41.41342105263158,
#    'avg_distance': 6.467894736842105,
#    'trip_count': 38,
#    'maps_url': 'https://www.google.com/maps?q=40.587183214502495,-74.22703511756104'},
#   {'zone': 'Longwood',
#    'peak_hour': 8,
#    'avg_earning': 26.937297297297295,
#    'avg_distance': 9.575675675675674,
#    'trip_count': 37,
#    'maps_url': 'https://www.google.com/maps?q=40.5034760652656,-74.04481949576498'},
#   {'zone': 'Schuylerville/Edgewater Park',
#    'peak_hour': 22,
#    'avg_earning': 28.918108108108108,
#    'avg_distance': 7.642162162162162,
#    'trip_count': 37,
#    'maps_url': 'https://www.google.com/maps?q=40.62092614545023,-74.24178959490864'},
#   {'zone': 'Midwood',
#    'peak_hour': 5,
#    'avg_earning': 20.534166666666668,
#    'avg_distance': 4.413333333333333,
#    'trip_count': 36,
#    'maps_url': 'https://www.google.com/maps?q=40.80478216698995,-73.6788696314064'},
#   {'zone': 'Mount Hope',
#    'peak_hour': 9,
#    'avg_earning': 26.523611111111112,
#    'avg_distance': 5.585,
#    'trip_count': 36,
#    'maps_url': 'https://www.google.com/maps?q=40.95413294298333,-73.95680477809998'},
#   {'zone': 'Ozone Park',
#    'peak_hour': 13,
#    'avg_earning': 30.914722222222224,
#    'avg_distance': 6.305,
#    'trip_count': 36,
#    'maps_url': 'https://www.google.com/maps?q=40.81615291529679,-73.57569441886459'},
#   {'zone': 'Springfield Gardens North',
#    'peak_hour': 8,
#    'avg_earning': 30.28083333333333,
#    'avg_distance': 8.232222222222223,
#    'trip_count': 36,
#    'maps_url': 'https://www.google.com/maps?q=40.88993777292881,-73.5111991489417'},
#   {'zone': 'Van Cortlandt Village',
#    'peak_hour': 21,
#    'avg_earning': 33.49944444444444,
#    'avg_distance': 9.201666666666666,
#    'trip_count': 36,
#    'maps_url': 'https://www.google.com/maps?q=40.546837383914045,-73.52942196844751'},
#   {'zone': 'Coney Island',
#    'peak_hour': 8,
#    'avg_earning': 38.08342857142858,
#    'avg_distance': 9.877142857142857,
#    'trip_count': 35,
#    'maps_url': 'https://www.google.com/maps?q=40.7200762468698,-73.92752158549403'},
#   {'zone': 'Hillcrest/Pomonok',
#    'peak_hour': 5,
#    'avg_earning': 22.53457142857143,
#    'avg_distance': 5.484857142857143,
#    'trip_count': 35,
#    'maps_url': 'https://www.google.com/maps?q=40.657177990538166,-73.79931206742862'},
#   {'zone': 'Bensonhurst West',
#    'peak_hour': 0,
#    'avg_earning': 23.986857142857144,
#    'avg_distance': 5.057142857142857,
#    'trip_count': 35,
#    'maps_url': 'https://www.google.com/maps?q=40.5290418060841,-74.04646239587498'},
#   {'zone': 'Brighton Beach',
#    'peak_hour': 8,
#    'avg_earning': 37.014242424242425,
#    'avg_distance': 10.540909090909091,
#    'trip_count': 33,
#    'maps_url': 'https://www.google.com/maps?q=40.606169555339136,-73.80799421864066'},
#   {'zone': 'Claremont/Bathgate',
#    'peak_hour': 6,
#    'avg_earning': 28.735454545454544,
#    'avg_distance': 6.815151515151515,
#    'trip_count': 33,
#    'maps_url': 'https://www.google.com/maps?q=40.58526206184364,-73.73842649819383'},
#   {'zone': 'Roosevelt Island',
#    'peak_hour': 14,
#    'avg_earning': 27.025757575757577,
#    'avg_distance': 4.579393939393939,
#    'trip_count': 33,
#    'maps_url': 'https://www.google.com/maps?q=40.93866967669049,-74.18560665435773'},
#   {'zone': 'Hammels/Arverne',
#    'peak_hour': 10,
#    'avg_earning': 43.82424242424243,
#    'avg_distance': 12.152121212121212,
#    'trip_count': 33,
#    'maps_url': 'https://www.google.com/maps?q=40.51270956337205,-73.80731992155823'},
#   {'zone': 'Kew Gardens Hills',
#    'peak_hour': 9,
#    'avg_earning': 30.761875,
#    'avg_distance': 9.1571875,
#    'trip_count': 32,
#    'maps_url': 'https://www.google.com/maps?q=40.90183603844956,-73.86350656854725'},
#   {'zone': 'Prospect Park',
#    'peak_hour': 19,
#    'avg_earning': 26.576451612903227,
#    'avg_distance': 5.280967741935484,
#    'trip_count': 31,
#    'maps_url': 'https://www.google.com/maps?q=40.50829391446393,-73.76198523513837'},
#   {'zone': 'Spuyten Duyvil/Kingsbridge',
#    'peak_hour': 7,
#    'avg_earning': 37.815666666666665,
#    'avg_distance': 8.986333333333334,
#    'trip_count': 30,
#    'maps_url': 'https://www.google.com/maps?q=40.54206998249752,-73.99899233157527'},
#   {'zone': 'Soundview/Bruckner',
#    'peak_hour': 9,
#    'avg_earning': 28.76241379310345,
#    'avg_distance': 6.770689655172413,
#    'trip_count': 29,
#    'maps_url': 'https://www.google.com/maps?q=40.81655072863664,-74.23212982873184'},
#   {'zone': 'Westchester Village/Unionport',
#    'peak_hour': 11,
#    'avg_earning': 29.224827586206896,
#    'avg_distance': 6.93,
#    'trip_count': 29,
#    'maps_url': 'https://www.google.com/maps?q=40.7513185465526,-73.52455797150472'},
#   {'zone': 'West Farms/Bronx River',
#    'peak_hour': 14,
#    'avg_earning': 26.75,
#    'avg_distance': 6.4799999999999995,
#    'trip_count': 29,
#    'maps_url': 'https://www.google.com/maps?q=40.81556931299863,-74.24096274821167'},
#   {'zone': 'Hunts Point',
#    'peak_hour': 7,
#    'avg_earning': 29.91862068965517,
#    'avg_distance': 5.105862068965517,
#    'trip_count': 29,
#    'maps_url': 'https://www.google.com/maps?q=40.87777556927153,-74.24354500207966'},
#   {'zone': 'Woodlawn/Wakefield',
#    'peak_hour': 8,
#    'avg_earning': 31.189655172413794,
#    'avg_distance': 7.3117241379310345,
#    'trip_count': 29,
#    'maps_url': 'https://www.google.com/maps?q=40.970229292176455,-74.07522944832621'},
#   {'zone': 'Crotona Park East',
#    'peak_hour': 14,
#    'avg_earning': 21.830689655172414,
#    'avg_distance': 4.669310344827586,
#    'trip_count': 29,
#    'maps_url': 'https://www.google.com/maps?q=40.95466020103939,-74.27559980004875'},
#   {'zone': 'East Tremont',
#    'peak_hour': 8,
#    'avg_earning': 33.915517241379305,
#    'avg_distance': 7.931379310344827,
#    'trip_count': 29,
#    'maps_url': 'https://www.google.com/maps?q=40.63567451588695,-73.66385104418504'},
#   {'zone': 'Far Rockaway',
#    'peak_hour': 8,
#    'avg_earning': 47.9925,
#    'avg_distance': 13.965,
#    'trip_count': 28,
#    'maps_url': 'https://www.google.com/maps?q=40.993443468300256,-73.97283764446858'},
#   {'zone': 'Bedford Park',
#    'peak_hour': 15,
#    'avg_earning': 29.951428571428572,
#    'avg_distance': 7.389285714285714,
#    'trip_count': 28,
#    'maps_url': 'https://www.google.com/maps?q=40.865996970905705,-73.61759243562611'},
#   {'zone': 'Eastchester',
#    'peak_hour': 23,
#    'avg_earning': 31.338148148148147,
#    'avg_distance': 9.146296296296295,
#    'trip_count': 27,
#    'maps_url': 'https://www.google.com/maps?q=40.64046725484369,-74.23723489492619'},
#   {'zone': 'Madison',
#    'peak_hour': 14,
#    'avg_earning': 21.791851851851852,
#    'avg_distance': 4.267407407407408,
#    'trip_count': 27,
#    'maps_url': 'https://www.google.com/maps?q=40.70870550157439,-74.28138245141133'},
#   {'zone': 'Gravesend',
#    'peak_hour': 8,
#    'avg_earning': 30.672400000000003,
#    'avg_distance': 6.3196,
#    'trip_count': 25,
#    'maps_url': 'https://www.google.com/maps?q=40.736107462580975,-73.6156315327912'},
#   {'zone': 'College Point',
#    'peak_hour': 10,
#    'avg_earning': 29.674400000000002,
#    'avg_distance': 7.260800000000001,
#    'trip_count': 25,
#    'maps_url': 'https://www.google.com/maps?q=40.54883605700319,-73.83737588720307'},
#   {'zone': 'Norwood',
#    'peak_hour': 10,
#    'avg_earning': 33.65833333333333,
#    'avg_distance': 9.009583333333333,
#    'trip_count': 24,
#    'maps_url': 'https://www.google.com/maps?q=40.62102763575575,-73.89579810204171'},
#   {'zone': 'Whitestone',
#    'peak_hour': 21,
#    'avg_earning': 63.83909090909091,
#    'avg_distance': 7.099545454545455,
#    'trip_count': 22,
#    'maps_url': 'https://www.google.com/maps?q=40.74625884690944,-73.79648108949179'},
#   {'zone': 'Bellerose',
#    'peak_hour': 22,
#    'avg_earning': 26.764090909090907,
#    'avg_distance': 9.125454545454547,
#    'trip_count': 22,
#    'maps_url': 'https://www.google.com/maps?q=40.79932924209852,-74.06444088634433'},
#   {'zone': 'Sheepshead Bay',
#    'peak_hour': 14,
#    'avg_earning': 22.14,
#    'avg_distance': 4.0842857142857145,
#    'trip_count': 21,
#    'maps_url': 'https://www.google.com/maps?q=40.94860787897667,-73.7350062182748'},
#   {'zone': 'Glen Oaks',
#    'peak_hour': 0,
#    'avg_earning': 27.15952380952381,
#    'avg_distance': 7.655714285714285,
#    'trip_count': 21,
#    'maps_url': 'https://www.google.com/maps?q=40.65549116085783,-73.6937231116285'},
#   {'zone': 'Kingsbridge Heights',
#    'peak_hour': 7,
#    'avg_earning': 23.122,
#    'avg_distance': 4.3469999999999995,
#    'trip_count': 20,
#    'maps_url': 'https://www.google.com/maps?q=40.59328502944302,-73.54682815297878'},
#   {'zone': 'Homecrest',
#    'peak_hour': 11,
#    'avg_earning': 31.442500000000003,
#    'avg_distance': 8.0145,
#    'trip_count': 20,
#    'maps_url': 'https://www.google.com/maps?q=40.95378323696305,-73.61480812704934'},
#   {'zone': 'Columbia Street',
#    'peak_hour': 11,
#    'avg_earning': 28.847,
#    'avg_distance': 5.218500000000001,
#    'trip_count': 20,
#    'maps_url': 'https://www.google.com/maps?q=40.84211651325608,-74.2712461809626'},
#   {'zone': 'Sunset Park East',
#    'peak_hour': 7,
#    'avg_earning': 31.0645,
#    'avg_distance': 5.3885,
#    'trip_count': 20,
#    'maps_url': 'https://www.google.com/maps?q=40.50253079192311,-73.90589991656731'},
#   {'zone': 'Queensboro Hill',
#    'peak_hour': 16,
#    'avg_earning': 22.959,
#    'avg_distance': 5.68,
#    'trip_count': 20,
#    'maps_url': 'https://www.google.com/maps?q=40.613247887598966,-73.66673676501932'},
#   {'zone': 'Dyker Heights',
#    'peak_hour': 7,
#    'avg_earning': 26.552,
#    'avg_distance': 6.171,
#    'trip_count': 20,
#    'maps_url': 'https://www.google.com/maps?q=40.98479231388228,-74.12734317800252'},
#   {'zone': 'Pelham Parkway',
#    'peak_hour': 11,
#    'avg_earning': 28.165,
#    'avg_distance': 6.608499999999999,
#    'trip_count': 20,
#    'maps_url': 'https://www.google.com/maps?q=40.66039003248587,-73.84124968950137'},
#   {'zone': 'Allerton/Pelham Gardens',
#    'peak_hour': 7,
#    'avg_earning': 29.94,
#    'avg_distance': 6.322631578947369,
#    'trip_count': 19,
#    'maps_url': 'https://www.google.com/maps?q=40.8655,-73.8565'},
#   {'zone': 'Belmont',
#    'peak_hour': 6,
#    'avg_earning': 21.88421052631579,
#    'avg_distance': 4.895263157894737,
#    'trip_count': 19,
#    'maps_url': 'https://www.google.com/maps?q=40.57800932022122,-73.99192181711845'},
#   {'zone': 'Windsor Terrace',
#    'peak_hour': 0,
#    'avg_earning': 28.02,
#    'avg_distance': 6.046111111111111,
#    'trip_count': 18,
#    'maps_url': 'https://www.google.com/maps?q=40.822736147953584,-73.57907359160721'},
#   {'zone': 'Rosedale',
#    'peak_hour': 11,
#    'avg_earning': 39.840555555555554,
#    'avg_distance': 8.871666666666666,
#    'trip_count': 18,
#    'maps_url': 'https://www.google.com/maps?q=40.62897081385758,-73.69079149462603'},
#   {'zone': 'Saint Michaels Cemetery/Woodside',
#    'peak_hour': 9,
#    'avg_earning': 49.35,
#    'avg_distance': 5.40764705882353,
#    'trip_count': 17,
#    'maps_url': 'https://www.google.com/maps?q=40.764825289178006,-73.7392246948327'},
#   {'zone': 'Murray Hill-Queens',
#    'peak_hour': 8,
#    'avg_earning': 34.66470588235294,
#    'avg_distance': 8.32294117647059,
#    'trip_count': 17,
#    'maps_url': 'https://www.google.com/maps?q=40.572447436045614,-73.69636570073226'},
#   {'zone': 'Manhattan Beach',
#    'peak_hour': 10,
#    'avg_earning': 25.585882352941177,
#    'avg_distance': 8.180588235294117,
#    'trip_count': 17,
#    'maps_url': 'https://www.google.com/maps?q=40.611053905235366,-73.64842521392885'},
#   {'zone': 'Riverdale/North Riverdale/Fieldston',
#    'peak_hour': 14,
#    'avg_earning': 45.722941176470584,
#    'avg_distance': 8.280588235294118,
#    'trip_count': 17,
#    'maps_url': 'https://www.google.com/maps?q=40.556736760620296,-74.01926798995834'},
#   {'zone': 'Bayside',
#    'peak_hour': 16,
#    'avg_earning': 21.404117647058825,
#    'avg_distance': 6.5723529411764705,
#    'trip_count': 17,
#    'maps_url': 'https://www.google.com/maps?q=40.68727005942368,-73.52667614476506'},
#   {'zone': 'Bensonhurst East',
#    'peak_hour': 15,
#    'avg_earning': 22.098125,
#    'avg_distance': 4.41625,
#    'trip_count': 16,
#    'maps_url': 'https://www.google.com/maps?q=40.5779972601681,-73.61909066278652'},
#   {'zone': 'Bronxdale',
#    'peak_hour': 9,
#    'avg_earning': 30.804375,
#    'avg_distance': 7.570625,
#    'trip_count': 16,
#    'maps_url': 'https://www.google.com/maps?q=40.652121121479766,-73.88533627810901'},
#   {'zone': 'Cambria Heights',
#    'peak_hour': 4,
#    'avg_earning': 38.600625,
#    'avg_distance': 10.981875,
#    'trip_count': 16,
#    'maps_url': 'https://www.google.com/maps?q=40.64607232426761,-74.06512652458841'},
#   {'zone': 'Fordham South',
#    'peak_hour': 9,
#    'avg_earning': 21.394375,
#    'avg_distance': 4.06375,
#    'trip_count': 16,
#    'maps_url': 'https://www.google.com/maps?q=40.53702232586704,-73.53610777546945'},
#   {'zone': 'Hollis',
#    'peak_hour': 6,
#    'avg_earning': 27.282,
#    'avg_distance': 7.1353333333333335,
#    'trip_count': 15,
#    'maps_url': 'https://www.google.com/maps?q=40.75428534558235,-73.89749099313593'},
#   {'zone': 'Marble Hill',
#    'peak_hour': 18,
#    'avg_earning': 18.489285714285717,
#    'avg_distance': 4461.705714285715,
#    'trip_count': 14,
#    'maps_url': 'https://www.google.com/maps?q=40.97145485195626,-73.74261026770868'},
#   {'zone': 'Fresh Meadows',
#    'peak_hour': 11,
#    'avg_earning': 31.186153846153847,
#    'avg_distance': 6.322307692307692,
#    'trip_count': 13,
#    'maps_url': 'https://www.google.com/maps?q=40.81164906341378,-73.96431995005777'},
#   {'zone': 'Van Nest/Morris Park',
#    'peak_hour': 8,
#    'avg_earning': 28.702727272727273,
#    'avg_distance': 6.943636363636363,
#    'trip_count': 11,
#    'maps_url': 'https://www.google.com/maps?q=40.68385790152972,-74.29027642024815'},
#   {'zone': 'Rockaway Park',
#    'peak_hour': 14,
#    'avg_earning': 36.82181818181818,
#    'avg_distance': 10.236363636363636,
#    'trip_count': 11,
#    'maps_url': 'https://www.google.com/maps?q=40.96234680913928,-74.20634638685792'},
#   {'zone': 'Bath Beach',
#    'peak_hour': 17,
#    'avg_earning': 27.993636363636366,
#    'avg_distance': 4.483636363636363,
#    'trip_count': 11,
#    'maps_url': 'https://www.google.com/maps?q=40.6023,-74.0119'},
#   {'zone': 'East Flushing',
#    'peak_hour': 10,
#    'avg_earning': 21.25,
#    'avg_distance': 5.397,
#    'trip_count': 10,
#    'maps_url': 'https://www.google.com/maps?q=40.54424625102596,-73.79005607880143'},
#   {'zone': 'Bronx Park',
#    'peak_hour': 6,
#    'avg_earning': 28.038999999999998,
#    'avg_distance': 9.994,
#    'trip_count': 10,
#    'maps_url': 'https://www.google.com/maps?q=40.59170225492672,-74.18793278781078'},
#   {'zone': 'Laurelton',
#    'peak_hour': 22,
#    'avg_earning': 29.266000000000002,
#    'avg_distance': 7.123,
#    'trip_count': 10,
#    'maps_url': 'https://www.google.com/maps?q=40.90372007758203,-73.57571948643515'},
#   {'zone': 'Ocean Parkway South',
#    'peak_hour': 11,
#    'avg_earning': 25.633,
#    'avg_distance': 3.125,
#    'trip_count': 10,
#    'maps_url': 'https://www.google.com/maps?q=40.86410817430593,-73.98863865701267'},
#   {'zone': 'Forest Park/Highland Park',
#    'peak_hour': 10,
#    'avg_earning': 24.874444444444446,
#    'avg_distance': 6.044444444444444,
#    'trip_count': 9,
#    'maps_url': 'https://www.google.com/maps?q=40.55793452976256,-73.85651675799087'},
#   {'zone': 'Arrochar/Fort Wadsworth',
#    'peak_hour': 15,
#    'avg_earning': 8.455,
#    'avg_distance': 5.3375,
#    'trip_count': 8,
#    'maps_url': 'https://www.google.com/maps?q=40.5966,-74.0576'},
#   {'zone': 'Bay Terrace/Fort Totten',
#    'peak_hour': 22,
#    'avg_earning': 37.8975,
#    'avg_distance': 11.8125,
#    'trip_count': 8,
#    'maps_url': 'https://www.google.com/maps?q=40.782,-73.7802'},
#   {'zone': 'Douglaston',
#    'peak_hour': 6,
#    'avg_earning': 41.832499999999996,
#    'avg_distance': 9.69625,
#    'trip_count': 8,
#    'maps_url': 'https://www.google.com/maps?q=40.7600340105889,-74.19835158987848'},
#   {'zone': 'Bloomfield/Emerson Hill',
#    'peak_hour': 21,
#    'avg_earning': 84.6275,
#    'avg_distance': 11.3575,
#    'trip_count': 8,
#    'maps_url': 'https://www.google.com/maps?q=40.933088072887465,-74.16440580265112'},
#   {'zone': 'Oakland Gardens',
#    'peak_hour': 8,
#    'avg_earning': 36.27142857142857,
#    'avg_distance': 11.15,
#    'trip_count': 7,
#    'maps_url': 'https://www.google.com/maps?q=40.836067773702936,-73.6388340271138'},
#   {'zone': 'Astoria Park',
#    'peak_hour': 7,
#    'avg_earning': 30.7,
#    'avg_distance': 7.228333333333333,
#    'trip_count': 6,
#    'maps_url': 'https://www.google.com/maps?q=40.772,-73.93'},
#   {'zone': 'Marine Park/Floyd Bennett Field',
#    'peak_hour': 15,
#    'avg_earning': 47.465,
#    'avg_distance': 8.361666666666666,
#    'trip_count': 6,
#    'maps_url': 'https://www.google.com/maps?q=40.66160146601037,-73.7968457225761'},
#   {'zone': 'Van Cortlandt Park',
#    'peak_hour': 10,
#    'avg_earning': 46.125,
#    'avg_distance': 12.104999999999999,
#    'trip_count': 6,
#    'maps_url': 'https://www.google.com/maps?q=40.78415430166773,-74.12112332918444'},
#   {'zone': 'City Island',
#    'peak_hour': 19,
#    'avg_earning': 38.74333333333333,
#    'avg_distance': 9.41,
#    'trip_count': 6,
#    'maps_url': 'https://www.google.com/maps?q=40.80377242595072,-73.7800288553778'},
#   {'zone': 'Auburndale',
#    'peak_hour': 19,
#    'avg_earning': 31.39,
#    'avg_distance': 2.66,
#    'trip_count': 4,
#    'maps_url': 'https://www.google.com/maps?q=40.7615,-73.7801'},
#   {'zone': 'Pelham Bay',
#    'peak_hour': 5,
#    'avg_earning': 24.195,
#    'avg_distance': 6.2,
#    'trip_count': 4,
#    'maps_url': 'https://www.google.com/maps?q=40.545144885027206,-73.53995042635935'},
#   {'zone': 'Westerleigh',
#    'peak_hour': 8,
#    'avg_earning': 62.0175,
#    'avg_distance': 5.467499999999999,
#    'trip_count': 4,
#    'maps_url': 'https://www.google.com/maps?q=40.78845194231318,-73.88152172466388'},
#   {'zone': 'Stapleton',
#    'peak_hour': 1,
#    'avg_earning': 29.2875,
#    'avg_distance': 10.9725,
#    'trip_count': 4,
#    'maps_url': 'https://www.google.com/maps?q=40.58081435704731,-74.23319942664106'},
#   {'zone': 'Grymes Hill/Clifton',
#    'peak_hour': 6,
#    'avg_earning': 61.405,
#    'avg_distance': 6.17,
#    'trip_count': 4,
#    'maps_url': 'https://www.google.com/maps?q=40.761366414691,-73.95291868060961'},
#   {'zone': 'Highbridge Park',
#    'peak_hour': 0,
#    'avg_earning': 20.523333333333333,
#    'avg_distance': 2.6199999999999997,
#    'trip_count': 3,
#    'maps_url': 'https://www.google.com/maps?q=40.81820520563189,-74.00030990829882'},
#   {'zone': 'Heartland Village/Todt Hill',
#    'peak_hour': 10,
#    'avg_earning': 25.195,
#    'avg_distance': 8.370000000000001,
#    'trip_count': 2,
#    'maps_url': 'https://www.google.com/maps?q=40.55394571349665,-73.79192507930588'},
#   {'zone': 'Green-Wood Cemetery',
#    'peak_hour': 17,
#    'avg_earning': 26.5,
#    'avg_distance': 3.6,
#    'trip_count': 2,
#    'maps_url': 'https://www.google.com/maps?q=40.88039252430845,-74.2217326714792'},
#   {'zone': 'Inwood Hill Park',
#    'peak_hour': 17,
#    'avg_earning': 11.49,
#    'avg_distance': 1.82,
#    'trip_count': 2,
#    'maps_url': 'https://www.google.com/maps?q=40.5384899549144,-74.2787909515667'},
#   {'zone': 'South Beach/Dongan Hills',
#    'peak_hour': 17,
#    'avg_earning': 5.03,
#    'avg_distance': 0.67,
#    'trip_count': 2,
#    'maps_url': 'https://www.google.com/maps?q=40.67460478730633,-74.00058336339511'},
#   {'zone': 'Pelham Bay Park',
#    'peak_hour': 14,
#    'avg_earning': -1.335,
#    'avg_distance': 10.25,
#    'trip_count': 2,
#    'maps_url': 'https://www.google.com/maps?q=40.917651247794616,-73.53951428244996'},
#   {'zone': 'Country Club',
#    'peak_hour': 8,
#    'avg_earning': 37.51,
#    'avg_distance': 11.355,
#    'trip_count': 2,
#    'maps_url': 'https://www.google.com/maps?q=40.747588455055634,-74.07076699829737'},
#   {'zone': 'New Dorp/Midland Beach',
#    'peak_hour': 15,
#    'avg_earning': 35.68,
#    'avg_distance': 12.7,
#    'trip_count': 1,
#    'maps_url': 'https://www.google.com/maps?q=40.74472638013878,-74.21750090493126'},
#   {'zone': 'Willets Point',
#    'peak_hour': 15,
#    'avg_earning': 7.9,
#    'avg_distance': 1.48,
#    'trip_count': 1,
#    'maps_url': 'https://www.google.com/maps?q=40.59762149389902,-73.7434010488123'},
#   {'zone': 'Port Richmond',
#    'peak_hour': 0,
#    'avg_earning': 35.98,
#    'avg_distance': 11.4,
#    'trip_count': 1,
#    'maps_url': 'https://www.google.com/maps?q=40.52038757077738,-73.94124358241734'},
#   {'zone': 'Saint George/New Brighton',
#    'peak_hour': 7,
#    'avg_earning': 14.9,
#    'avg_distance': 3.01,
#    'trip_count': 1,
#    'maps_url': 'https://www.google.com/maps?q=40.77760040579973,-74.232714555108'},
#   {'zone': 'Rossville/Woodrow',
#    'peak_hour': 13,
#    'avg_earning': 144.76,
#    'avg_distance': 0.0,
#    'trip_count': 1,
#    'maps_url': 'https://www.google.com/maps?q=40.82999202301709,-73.80542554934699'},
#   {'zone': 'West Brighton',
#    'peak_hour': 4,
#    'avg_earning': 60.0,
#    'avg_distance': 0.0,
#    'trip_count': 1,
#    'maps_url': 'https://www.google.com/maps?q=40.986505277376224,-73.58708550904154'},
#   {'zone': 'Breezy Point/Fort Tilden/Riis Beach',
#    'peak_hour': 7,
#    'avg_earning': 21.2,
#    'avg_distance': 5.3,
#    'trip_count': 1,
#    'maps_url': 'https://www.google.com/maps?q=40.984954926081,-73.8439510639285'},
#   {'zone': 'Broad Channel',
#    'peak_hour': 14,
#    'avg_earning': 30.79,
#    'avg_distance': 0.0,
#    'trip_count': 1,
#    'maps_url': 'https://www.google.com/maps?q=40.59091248360355,-73.5079569199166'},
#   {'zone': 'Oakwood',
#    'peak_hour': 4,
#    'avg_earning': 120.0,
#    'avg_distance': 0.0,
#    'trip_count': 1,
#    'maps_url': 'https://www.google.com/maps?q=40.88080980766436,-74.04396031917551'}]}

# %%
get_weekly_demand_chart("Sunday")

# %%
response = predict_demand(pickup_hour=18, day_of_week=1, zone="JFK Airport")
print(response)
# Out:
# {'status': 'success', 'predicted_fare': 60.05552092001337}
# c:\Users\jerom\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names

# %% [markdown]
# # Posibles mejoras por realizar.
#
# 1. Integración de Datos en Tiempo Real:
#
# - Incorporar datos de tráfico, clima y eventos locales para ajustar las predicciones y recomendaciones en tiempo real.
#
# 2. Predicciones Más Sofisticadas:
#
# - Usar modelos avanzados como XGBoost o redes neuronales para mejorar la exactitud de las predicciones.
# - Incorporar variables adicionales como patrones estacionales, datos climáticos, y tendencias económicas.
#
# 3. Visualización Interactiva:
#
# - Integrar gráficos y mapas interactivos con herramientas como Plotly, Dash, o Streamlit.

# %% [markdown]
# # Ejemplo de implementación de mejora. Modelo 2.

# %%
from fastapi import FastAPI
import pandas as pd
import numpy as np
import plotly.express as px
from fastapi.responses import FileResponse, JSONResponse
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

# Load datasets
taxi_data_path = 'Yellow_Tripdata_2024-10_reducido.csv'
zone_data_path = 'transformed_taxi_zone_merged_with_locations.csv'

taxi_data = pd.read_csv(taxi_data_path)
zone_data = pd.read_csv(zone_data_path)

# Create FastAPI app
app = FastAPI()

# Preprocess data
data = taxi_data.merge(zone_data, left_on='PULocationID', right_on='locationid_x', how='left')
data['pickup_hour'] = pd.to_datetime(data['tpep_pickup_datetime']).dt.hour
data['pickup_day'] = pd.to_datetime(data['tpep_pickup_datetime']).dt.day_name()
data['day_of_week'] = pd.to_datetime(data['tpep_pickup_datetime']).dt.dayofweek  # 0=Monday, 6=Sunday

# Train XGBoost model
def train_demand_prediction_model():
    # Prepare data for machine learning
    features = data[['pickup_hour', 'day_of_week', 'zone_latitude', 'zone_longitude']]
    target = data['fare_amount']

    # Split data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

    # Train an XGBoost Regressor
    model = XGBRegressor(n_estimators=200, max_depth=6, learning_rate=0.1, random_state=42)
    model.fit(X_train, y_train)

    # Print model performance (optional)
    score = model.score(X_test, y_test)
    print(f"Model R^2 Score: {score:.2f}")

    return model

model = train_demand_prediction_model()

@app.get("/predict")
def predict_demand(pickup_hour: int, day_of_week: int, zone: str):
    """
    Predict demand based on input features.
    pickup_hour: Hour of the day (0-23).
    day_of_week: Day of the week (0=Monday, 6=Sunday).
    zone: Name of the zone.
    """
    try:
        # Get latitude and longitude for the zone
        if zone not in data['zone'].unique():
            return {"status": "error", "message": f"Zone '{zone}' not found in data."}

        zone_data = data[data['zone'] == zone].iloc[0]
        latitude = zone_data['zone_latitude']
        longitude = zone_data['zone_longitude']

        # Predict demand
        prediction = model.predict([[pickup_hour, day_of_week, latitude, longitude]])
        return {"status": "success", "predicted_fare": round(prediction[0], 2)}
    except Exception as e:
        return {"status": "error", "message": str(e)}
# Out:
# C:\Users\jerom\AppData\Local\Temp\ipykernel_21932\2270883427.py:13: DtypeWarning:
#
# Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
# Model R^2 Score: 0.32

# %%
response = predict_demand(pickup_hour=18, day_of_week=1, zone="JFK Airport")
print(response)
# Out:
# {'status': 'success', 'predicted_fare': 58.66}

# %% [markdown]
# # Cambios Clave
# 1. Reemplazo del Modelo:
#
# - RandomForestRegressor ha sido reemplazado por XGBRegressor con hiperparámetros iniciales:
#     + n_estimators=200: Cantidad de árboles.
#     + max_depth=6: Profundidad máxima de los árboles.
#     + learning_rate=0.1: Tasa de aprendizaje.
# 2. Validación del Modelo: Se calcula el coeficiente de determinación 𝑅2 en el conjunto de prueba.
# 3. Precisión Mejorada: XGBoost generalmente tiene mejor desempeño en conjuntos de datos tabulares y grandes.

# %% [markdown]
# # Posibles sobremejoras.
# 1. Optimización de Hiperparámetros:
#     -   Usa técnicas como búsqueda en cuadrícula (GridSearchCV) o búsqueda aleatoria (RandomizedSearchCV) para encontrar los mejores hiperparámetros.
# 2. Incorporar Variables Adicionales:
# Variables como el clima en tiempo real, eventos locales o estacionalidad podrían mejorar aún más la precisión del modelo.
